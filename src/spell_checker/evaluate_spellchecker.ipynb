# %%
import sys
import os

# Ensure the current directory is in the Python path
sys.path.append(os.getcwd())

from spell_checker import SpellChecker
from tests.spell_checker_evaluator import evaluate_spell_checker

correct_words_file = r"D:\7th Semester\AI\Tamil-SpellGrammar-Checker\data\processed\extracted_words.txt"

test_paragraphs_list = [
    "ஏற்றுமதயை நம்பியுள்ள நாடுகளுகுத்தான் இதனால் பாதிப்பு. உள்நாட்டிலேயே தேவை அதிகமக உள்ள இந்தியா போன்ற மக்கள் தொகை அதிகம் கொண்ட வளரும் பொருளதர நாட்டில் பிரச்சனை ஏற்படது என்று அவர் திடவட்டமாகக் கூறினார்.",
    "இந்த நாளில், வடலர் வள்ளலர் கோயிலில், லட்சக்ணக்கான பக்தர்கள் தரிசனம் செய்வார்கள். அருட்பருஞ் ஜோதி தனப்பெருங்கருணை என்று கோஷங்ள் முழங்க, வள்ளலரை வணங்குவார்கள். வருவோருக்கெல்லாம் அன்னதானம் தடையின்றி நடந்து கெண்டே இருக்கும்.",
    "வர்த்தக அமைசசகத்தின் கீழ செயல்படும் சரக்கு போக்கவரத்து துறயை ஏற்கெனவ வாகன உற்பத்தியாளர் சங்க பிரதிநிதிகள் அணுகி இந்த பிரச்சனை குறித்து விவாதித்துள்லனர். பன்முக வரி விதப்பு முறை குலப்பமாக உள்ளதையும் குறிப்பிட்டுள்ளனர்.",
    "இநதப் பேரலகியடன் ஒப்பந்தம் செய்யபட்டுள்ள படம் விரைவில் படப்பிடிப்பு தொடங்கவிருக்கிறது. இந்தப் படம் பெரும் பொருட்செலவில் தயாரிக்கவிருக்கறது. இப்படத்தின் நயகன் எனக்கு மகவும் பிடித்த நடிகர், அவர் சமயலின் சிறப்புக்கு எடுத்துக்காட்டாக விளங்குகிறார். படம் பற்றிய எதிர்பர்ப்புகள் அதிகமாக உள்ளன. படம் படப்பிடிப்பு முடிந்த பன்னர், அத மக்களுக்கு மிகவும் வரவேற்கப்படும் என நம்புறேன்.",
    "சூரபதமன் என்ற அரக்ன் சிறந்த சிவ பக்தன். அவன மிகப் பெரிய யகங்கள், தவங்கள் செய்து சிவபருமானின் நன்மதிப்பைப் பெற்றான். அவனுக்கு வரமலிக்க விரும்பினார் சிவன். ஈசன் உட்பட யாருக்கும் தன்னக் கெல்ல வல்லமை இருக்கக் கூடாது என்று வேண்டினன் சூரன்."
]

expected_paragraph = [
    "ஏற்றுமதியை நம்பியுள்ள நாடுகளுக்குத்தான் இதனால் பாதிப்பு. உள்நாட்டிலேயே தேவை அதிகமாக உள்ள இந்தியா போன்ற மக்கள் தொகை அதிகம் கொண்ட வளரும் பொருளாதார நாட்டில் பிரச்சனை ஏற்படாது என்று அவர் திட்டவட்டமாகக் கூறினார்.",
    "இந்த நாளில், வடலூர் வள்ளலார் கோயிலில், லட்சக்கணக்கான பக்தர்கள் தரிசனம் செய்வார்கள். அருட்பெருஞ் ஜோதி தனிப்பெருங்கருணை என்று கோஷங்கள் முழங்க, வள்ளலாரை வணங்குவார்கள். வருவோருக்கெல்லாம் அன்னதானம் தடையின்றி நடந்து கொண்டே இருக்கும்.",
    "வர்த்தக அமைச்சகத்தின் கீழ் செயல்படும் சரக்கு போக்குவரத்து துறையை ஏற்கெனவே வாகன உற்பத்தியாளர் சங்க பிரதிநிதிகள் அணுகி இந்த பிரச்சினை குறித்து விவாதித்துள்ளனர். பன்முக வரி விதிப்பு முறை குழப்பமாக உள்ளதையும் குறிப்பிட்டுள்ளனர்.",
    "இந்தப் பேரழகியுடன் ஒப்பந்தம் செய்யப்பட்டுள்ள படம் விரைவில் படப்பிடிப்பு தொடங்கவிருக்கிறது. இந்தப் படம் பெரும் பொருட்செலவில் தயாரிக்கவிருக்கிறது. இப்படத்தின் நாயகன் எனக்கு மிகவும் பிடித்த நடிகர், அவர் சமையலின் சிறப்புக்கு எடுத்துக்காட்டாக விளங்குகிறார். படம் பற்றிய எதிர்பார்ப்புகள் அதிகமாக உள்ளன. படம் படப்பிடிப்பு முடிந்த பின்னர், அது மக்களுக்கு மிகவும் வரவேற்கப்படும் என நம்புகிறேன்.",
    "சூரபதுமன் என்ற அரக்கன் சிறந்த சிவ பக்தன். அவன் மிகப் பெரிய யாகங்கள், தவங்கள் செய்து சிவபெருமானின் நன்மதிப்பைப் பெற்றான். அவனுக்கு வரமளிக்க விரும்பினார் சிவன். ஈசன் உட்பட யாருக்கும் தன்னைக் கொல்ல வல்லமை இருக்கக் கூடாது என்று வேண்டினான் சூரன்."
]

# Split the text into sentences for checking
test_sentences = [para.rstrip(".").split(".") for para in test_paragraphs_list]
expected_sentences = [para.rstrip(".").split(".") for para in expected_paragraph]

# Loop through test paragraphs and perform spell/grammar correction
for idx, test_sentences_group in enumerate(test_sentences):
    print(f"\n\n--- Testing Paragraph {idx+1} ---")

    for i, sentence in enumerate(test_sentences_group):
        print(f"\nTest Sentence {i+1}: {sentence.strip()}")

        # Initialize the SpellChecker object
        spell_checker = SpellChecker(correct_words_file, sentence)
        corrected_text = spell_checker.correct()

        # Output the corrected text
        print(f"Corrected Text: {corrected_text.strip()}")
        print(f"Expected Text: {expected_sentences[idx][i].strip()}")

        # Evaluate the spell checker against the expected result
        # print("--- Evaluation Results ---")
        # evaluate_spell_checker(corrected_text, expected_sentences[idx][i], corrected_text)
# Out:
# --- Testing Paragraph 1 ---
#
# Test Sentence 1: ஏற்றுமதயை நம்பியுள்ள நாடுகளுகுத்தான் இதனால் பாதிப்பு
# Corrected Text: ஏற்றுமதியை நம்பியுள்ள நாடுகளுக்கும் இதனால் பாதிப்பு
# Expected Text: ஏற்றுமதியை நம்பியுள்ள நாடுகளுக்குத்தான் இதனால் பாதிப்பு
#
# Test Sentence 2: உள்நாட்டிலேயே தேவை அதிகமக உள்ள இந்தியா போன்ற மக்கள் தொகை அதிகம் கொண்ட வளரும் பொருளதர நாட்டில் பிரச்சனை ஏற்படது என்று அவர் திடவட்டமாகக் கூறினார்
# Corrected Text: உள்நாட்டிலேயே தேவை அதிகமாக உள்ள இந்தியா போன்ற மக்கள் தொகை அதிகம் கொண்ட வளரும் பொருள் நாட்டில் பிரச்சனை ஏற்படாது என்று அவர் திட்டினார் கூறினார்
# Expected Text: உள்நாட்டிலேயே தேவை அதிகமாக உள்ள இந்தியா போன்ற மக்கள் தொகை அதிகம் கொண்ட வளரும் பொருளாதார நாட்டில் பிரச்சனை ஏற்படாது என்று அவர் திட்டவட்டமாகக் கூறினார்
#
#
# --- Testing Paragraph 2 ---
#
# Test Sentence 1: இந்த நாளில், வடலர் வள்ளலர் கோயிலில், லட்சக்ணக்கான பக்தர்கள் தரிசனம் செய்வார்கள்
# Corrected Text: இந்த நாளில் வடலூர் வள்ளலார் கோயிலில் லட்சக்கணக்கான பக்தர்கள் தரிசனம் செய்வார்கள்
# Expected Text: இந்த நாளில், வடலூர் வள்ளலார் கோயிலில், லட்சக்கணக்கான பக்தர்கள் தரிசனம் செய்வார்கள்
#
# Test Sentence 2: அருட்பருஞ் ஜோதி தனப்பெருங்கருணை என்று கோஷங்ள் முழங்க, வள்ளலரை வணங்குவார்கள்
# Corrected Text: அருட்பெருஞ் ஜோதிட தன்ஷிகாவுக்கு என்று கோஷங்கள் முழங்க வள்ளலார் வணங்குவார்கள்
# Expected Text: அருட்பெருஞ் ஜோதி தனிப்பெருங்கருணை என்று கோஷங்கள் முழங்க, வள்ளலாரை வணங்குவார்கள்
#
# Test Sentence 3: வருவோருக்கெல்லாம் அன்னதானம் தடையின்றி நடந்து கெண்டே இருக்கும்
# Corrected Text: வருவோருக்கெல்லாம் அன்னதானம் தடையின்றி நடந்து கெட்டதோ இருக்கும்
# Expected Text: வருவோருக்கெல்லாம் அன்னதானம் தடையின்றி நடந்து கொண்டே இருக்கும்
#
#
# --- Testing Paragraph 3 ---
#
# Test Sentence 1: வர்த்தக அமைசசகத்தின் கீழ செயல்படும் சரக்கு போக்கவரத்து துறயை ஏற்கெனவ வாகன உற்பத்தியாளர் சங்க பிரதிநிதிகள் அணுகி இந்த பிரச்சனை குறித்து விவாதித்துள்லனர்
# Corrected Text: வர்த்தக அமைச்சருக்கு கீழ் செயல்படும் சரக்கு போக்கவேண்டிய துறை ஏற்கெனவே வாகன உற்பத்தியாளர் சங்க பிரதிநிதிகள் அணுகி இந்த பிரச்சனை குறித்து விவாதித்துள்ளனர்
# Expected Text: வர்த்தக அமைச்சகத்தின் கீழ் செயல்படும் சரக்கு போக்குவரத்து துறையை ஏற்கெனவே வாகன உற்பத்தியாளர் சங்க பிரதிநிதிகள் அணுகி இந்த பிரச்சினை குறித்து விவாதித்துள்ளனர்
#
# Test Sentence 2: பன்முக வரி விதப்பு முறை குலப்பமாக உள்ளதையும் குறிப்பிட்டுள்ளனர்
# Corrected Text: பன்முக வரி விதம் முறை குலத்து உள்ளதையும் குறிப்பிட்டுள்ளனர்
# Expected Text: பன்முக வரி விதிப்பு முறை குழப்பமாக உள்ளதையும் குறிப்பிட்டுள்ளனர்
#
#
# --- Testing Paragraph 4 ---
#
# Test Sentence 1: இநதப் பேரலகியடன் ஒப்பந்தம் செய்யபட்டுள்ள படம் விரைவில் படப்பிடிப்பு தொடங்கவிருக்கிறது
# Corrected Text: இந்த பேரண்டமாய் ஒப்பந்தம் செய்யப்பட்டு படம் விரைவில் படப்பிடிப்பு தொடங்கவிருக்கிறது
# Expected Text: இந்தப் பேரழகியுடன் ஒப்பந்தம் செய்யப்பட்டுள்ள படம் விரைவில் படப்பிடிப்பு தொடங்கவிருக்கிறது
#
# Test Sentence 2: இந்தப் படம் பெரும் பொருட்செலவில் தயாரிக்கவிருக்கறது
# Corrected Text: இந்தப் படம் பெரும் பொருட்செலவில் தயாரிக்கவிருக்கிறது
# Expected Text: இந்தப் படம் பெரும் பொருட்செலவில் தயாரிக்கவிருக்கிறது
#
# Test Sentence 3: இப்படத்தின் நயகன் எனக்கு மகவும் பிடித்த நடிகர், அவர் சமயலின் சிறப்புக்கு எடுத்துக்காட்டாக விளங்குகிறார்
# Corrected Text: இப்படத்தின் நிறைய எனக்கு மக்கள் பிடித்து நடிகர் அவர் சமயப் சிறப்புக்கு எடுத்துக்காட்டாக விளங்குகிறார்
# Expected Text: இப்படத்தின் நாயகன் எனக்கு மிகவும் பிடித்த நடிகர், அவர் சமையலின் சிறப்புக்கு எடுத்துக்காட்டாக விளங்குகிறார்
#
# Test Sentence 4: படம் பற்றிய எதிர்பர்ப்புகள் அதிகமாக உள்ளன
# Corrected Text: படம் பற்றிய எதிர்பார்ப்புகள் அதிகமாக உள்ளன
# Expected Text: படம் பற்றிய எதிர்பார்ப்புகள் அதிகமாக உள்ளன
#
# Test Sentence 5: படம் படப்பிடிப்பு முடிந்த பன்னர், அத மக்களுக்கு மிகவும் வரவேற்கப்படும் என நம்புறேன்
# Corrected Text: படம் படப்பிடிப்பு முடிந்த பன்னிரு அது மக்களுக்கு மிகவும் வரவேற்கலாம் என் நம்புகிறது
# Expected Text: படம் படப்பிடிப்பு முடிந்த பின்னர், அது மக்களுக்கு மிகவும் வரவேற்கப்படும் என நம்புகிறேன்
#
#
# --- Testing Paragraph 5 ---
#
# Test Sentence 1: சூரபதமன் என்ற அரக்ன் சிறந்த சிவ பக்தன்
# Corrected Text: சூரபத்மனை என்று அரக்கன் சிறந்த சிவா பக்தன்
# Expected Text: சூரபதுமன் என்ற அரக்கன் சிறந்த சிவ பக்தன்
#
# Test Sentence 2: அவன மிகப் பெரிய யகங்கள், தவங்கள் செய்து சிவபருமானின் நன்மதிப்பைப் பெற்றான்
# Corrected Text: அவன் மிகப் பெரிய யாரும் தவங்கள் செய்து சிவபெருமான் நன்மதிப்பைப் பெற்றான்
# Expected Text: அவன் மிகப் பெரிய யாகங்கள், தவங்கள் செய்து சிவபெருமானின் நன்மதிப்பைப் பெற்றான்
#
# Test Sentence 3: அவனுக்கு வரமலிக்க விரும்பினார் சிவன்
# Corrected Text: அவனுக்கு வரம்பு விரும்பினார் சிவன்
# Expected Text: அவனுக்கு வரமளிக்க விரும்பினார் சிவன்
#
# Test Sentence 4: ஈசன் உட்பட யாருக்கும் தன்னக் கெல்ல வல்லமை இருக்கக் கூடாது என்று வேண்டினன் சூரன்
# Corrected Text: ஈசன் உட்பட யாருக்கும் தன்னைக் கெட்ட வல்லமை இருக்கக் கூடாது என்று வேண்டினான் சூரன்
# Expected Text: ஈசன் உட்பட யாருக்கும் தன்னைக் கொல்ல வல்லமை இருக்கக் கூடாது என்று வேண்டினான் சூரன்
